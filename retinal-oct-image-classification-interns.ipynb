# %% [markdown]
# # Aim
# <div style = "text-align: justify">The aim of this notebook is to classify different kinds of retinal distortions namely, <b>choroidal neovascularization (CNV), Diabetic macular edema (DME) and Multiple drusen (DRUSEN).</b></div>
#
# # Dataset - [Link](https://www.kaggle.com/paultimothymooney/kermany2018)
# <div style = "text-align: justify">The dataset consists of 3 folders - <b>test, train and val,</b> and each folder in turn has four subfolders - <b>CNV, DME, DRUSEN, and NORMAL.</b> These folders contain images of respective diseases.</div>
#
# ![img](https://i.imgur.com/fSTeZMd.png)

# %% [markdown]
# # Credits

# %% [markdown]
# This notebook is built by KARTIKEY SHARMA and has been pulled out from Kaggle. Use this as a reference to cross-check and consolidate your work for the course outcome.
#
# I have highlighted over my code as to what more is achievable to superimpose and show the model learning boundaries and intuition. The aim there was to plausible identify and reason out why the model classified an image to be one of the four classes in consideraion.
#
# Hope this notebook helps and all the very best for your future endeavors.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL.Image import fromarray

# %%
img = cv2.imread('../input/chartdata/Capture.PNG')
plt.figure(figsize = (20,5))
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 945.5, 209.5, -0.5)

# %% [markdown]
# # Sources
#
# <div style = "text-align: justify">The OCT images were obtained from retrospective cohorts of adult patients from Shiley Eye Institute of the University of California San Diego, the California Retinal Research Foundation, Medical Center for Ophthalmology Associates, the Shanghai First People's Hospital, and Beijing Tongren Eye Center between July 1, 2013 and March 1, 2017.</div>

# %%
paths = ['../input/kermany2018/OCT2017 /train/',
         '../input/kermany2018/OCT2017 /test/',
         '../input/kermany2018/OCT2017 /val/']

# %%
import os
from keras.utils import to_categorical
from keras.preprocessing.image import img_to_array

# %%
def cvt_arr (impath) :
    return 
                        
def get_array (path) :
    
    X = []
    y = []
    
    for label, disease in enumerate(os.listdir(path)) :
        
        
        
        
        # resize and append
        for count, image in enumerate(os.listdir(os.path.join(path, disease))) :
            X.append(img_to_array(
                fromarray(
                    cv2.resize(
                        cv2.imread(
                            os.path.join(os.path.join(path, disease),image)),(128,128)))))
            
            # only 5k imgs
            y.append(label)
            if count > 5e3 :
                break
    
    X = np.array(X)
    y = np.array(y)
    
    return X/255.0, to_categorical(y)

# %%
X_train, y_train = get_array(paths[0])
print('training data extracted .....')
X_test , y_test  = get_array(paths[1])
print('testing data extracted ......')
X_valid, y_valid = get_array(paths[2])
print('validation data extracted ...')
# Out:
# training data extracted .....
# testing data extracted ......
# validation data extracted ...

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (20008, 128, 128, 3)
# (20008, 4)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (968, 128, 128, 3)
# (968, 4)

# %%
print(X_valid.shape)
print(y_valid.shape)
# Out:
# (32, 128, 128, 3)
# (32, 4)

# %%
print(X_train.min())
print(X_train.max())
# Out:
# 0.0
# 1.0

# %%
print(y_train.min())
print(y_train.max())
# Out:
# 0.0
# 1.0

# %% [markdown]
# # Image visualization & class distribution

# %%
info = {
    0 : 'DRUSEN',
    1 : 'CNV',
    2 : 'NORMAL',
    3 : 'DME',
}

# %%
plt.figure(figsize = (20,20))

i = 0

while i < 16 :
    
    x = np.random.randint(0, 20000)
    plt.subplot(4, 4, i+1)
    plt.imshow(X_train[x])
    plt.axis('off')
    plt.title(info[np.argmax(y_train[x])])
    
    i += 1
plt.show()

# %%
import seaborn
import pandas

# %% [markdown]
# Training data distribution

# %%
plt.figure(figsize = (20,5))

plt.subplot(1,2,1)
seaborn.histplot(data = pandas.DataFrame({'id' : np.argmax(y_train, axis = 1)}), x = 'id', bins = 8)
plt.title('Train label distribution', fontsize = 15)

plt.subplot(1,2,2)
seaborn.histplot(data = pandas.DataFrame({'id' : np.argmax(y_test , axis = 1)}), x = 'id', bins = 8)
plt.title('Test label distribution', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Test label distribution')

# %% [markdown]
# # Image Augmentation
#
# #### *Augment using ImageDataGenerator() with rotation by 15 deg, horizontal flips, height shift and zoom in by 20%.*

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
train_gen = ImageDataGenerator(rotation_range = 15, horizontal_flip = True, height_shift_range = [-5,5], zoom_range = [0.80, 1.00])

# %%
train_gen.fit(X_train)

# %%
point = train_gen.flow(X_train, y_train)

# %%
trainX, trainy = point.next()

# %%
plt.figure(figsize = (20,20))

i = 0

while i < 16 :
    
    x = np.random.randint(0, 32)
    plt.subplot(4, 4,i+1)
    plt.imshow(trainX[x])
    plt.axis('off')
    plt.title(info[np.argmax(trainy[x])])
    
    i += 1
plt.show()

# %% [markdown]
# # Model Architecture

# %%
from keras.layers import MaxPooling2D
from keras.models import Sequential
from keras.layers import Flatten
from keras.layers import Conv2D
from keras.layers import Dense
from keras.layers import Input
from keras.layers import Dropout
from keras.layers import LeakyReLU
from keras.layers import BatchNormalization

# %%
def conv_layer (filterx) :
    
    model = Sequential()
    
    model.add(Conv2D(filterx, (4,4), padding = 'same', use_bias = False))
    model.add(BatchNormalization())
    model.add(Dropout(.2))
    model.add(LeakyReLU())
    model.add(MaxPooling2D((2, 2)))
    
    return model

def dens_layer (hiddenx) :
    
    model = Sequential()
    
    model.add(Dense(hiddenx, kernel_regularizer = 'l2'))
    model.add(BatchNormalization())
    model.add(Dropout(.2))
    model.add(LeakyReLU())
    
    return model

# %%
def cnn (filter1, filter2, filter3, hidden1) :
    
    model = Sequential([
        
        Input((128,128,3,)),
        conv_layer(filter1),
        conv_layer(filter2),
        conv_layer(filter3),
        Flatten(),
        dens_layer(hidden1),
        Dense(4, activation = 'softmax')
    ])
    
    model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
    return model

# %%
model = cnn(16, 32, 64, 120)

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 64, 64, 16)        832
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 32, 32, 32)        8320
# _________________________________________________________________
# sequential_2 (Sequential)    (None, 16, 16, 64)        33024
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# sequential_3 (Sequential)    (None, 120)               1966680
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 484
# =================================================================
# Total params: 2,009,340
# Trainable params: 2,008,876
# Non-trainable params: 464
# _________________________________________________________________

# %%
import tensorflow as tf

# %%
tf.keras.utils.plot_model(model, './ret_model.png', show_shapes = True)

# %% [markdown]
# # fit()

# %%
checkp = tf.keras.callbacks.ModelCheckpoint('./ret_model.h5', monitor = 'val_loss', save_best_only = True, verbose = 1)

# %%
history = model.fit(train_gen.flow(X_train, y_train, batch_size = 64), epochs = 100, validation_data = (X_valid, y_valid), callbacks = [checkp])
# Out:
# Epoch 1/100
# 313/313 [==============================] - 68s 202ms/step - loss: 2.5721 - accuracy: 0.4336 - val_loss: 3.9034 - val_accuracy: 0.2500
#
# Epoch 00001: val_loss improved from inf to 3.90337, saving model to ./ret_model.h5
# Epoch 2/100
# 313/313 [==============================] - 63s 202ms/step - loss: 1.1239 - accuracy: 0.6520 - val_loss: 1.1747 - val_accuracy: 0.5312
#
# Epoch 00002: val_loss improved from 3.90337 to 1.17471, saving model to ./ret_model.h5
# Epoch 3/100
# 313/313 [==============================] - 64s 203ms/step - loss: 0.9373 - accuracy: 0.7277 - val_loss: 0.7869 - val_accuracy: 0.7812
#
# Epoch 00003: val_loss improved from 1.17471 to 0.78687, saving model to ./ret_model.h5
# Epoch 4/100
# 313/313 [==============================] - 63s 201ms/step - loss: 0.8550 - accuracy: 0.7547 - val_loss: 0.9861 - val_accuracy: 0.7500
#
# Epoch 00004: val_loss did not improve from 0.78687
# Epoch 5/100
# 313/313 [==============================] - 63s 202ms/step - loss: 0.8222 - accuracy: 0.7779 - val_loss: 0.7902 - val_accuracy: 0.8125
#
# Epoch 00005: val_loss did not improve from 0.78687
# Epoch 6/100
# 313/313 [==============================] - 65s 206ms/step - loss: 0.7942 - accuracy: 0.7829 - val_loss: 0.8405 - val_accuracy: 0.7500
#
# Epoch 00006: val_loss did not improve from 0.78687
# Epoch 7/100
# 313/313 [==============================] - 64s 203ms/step - loss: 0.7739 - accuracy: 0.7985 - val_loss: 1.5534 - val_accuracy: 0.5312
#
# Epoch 00007: val_loss did not improve from 0.78687
# Epoch 8/100
# 313/313 [==============================] - 63s 202ms/step - loss: 0.7594 - accuracy: 0.8075 - val_loss: 0.5247 - val_accuracy: 0.9375
#
# Epoch 00008: val_loss improved from 0.78687 to 0.52465, saving model to ./ret_model.h5
# Epoch 9/100
# 313/313 [==============================] - 62s 199ms/step - loss: 0.7205 - accuracy: 0.8202 - val_loss: 0.7628 - val_accuracy: 0.8125
#
# Epoch 00009: val_loss did not improve from 0.52465
# Epoch 10/100
# 313/313 [==============================] - 63s 201ms/step - loss: 0.7244 - accuracy: 0.8249 - val_loss: 0.9858 - val_accuracy: 0.7188
#
# Epoch 00010: val_loss did not improve from 0.52465
# Epoch 11/100
# 313/313 [==============================] - 62s 198ms/step - loss: 0.7170 - accuracy: 0.8232 - val_loss: 0.8307 - val_accuracy: 0.7500
#
# Epoch 00011: val_loss did not improve from 0.52465
# Epoch 12/100
# 313/313 [==============================] - 62s 197ms/step - loss: 0.7084 - accuracy: 0.8350 - val_loss: 0.7163 - val_accuracy: 0.7812
#
# Epoch 00012: val_loss did not improve from 0.52465
# Epoch 13/100
# 313/313 [==============================] - 62s 197ms/step - loss: 0.7150 - accuracy: 0.8299 - val_loss: 0.5117 - val_accuracy: 0.8438
#
# Epoch 00013: val_loss improved from 0.52465 to 0.51174, saving model to ./ret_model.h5
# Epoch 14/100
# 313/313 [==============================] - 62s 197ms/step - loss: 0.6956 - accuracy: 0.8366 - val_loss: 0.6499 - val_accuracy: 0.9375
#
# Epoch 00014: val_loss did not improve from 0.51174
# Epoch 15/100
# 313/313 [==============================] - 62s 199ms/step - loss: 0.6900 - accuracy: 0.8375 - val_loss: 0.5506 - val_accuracy: 0.8438
#
# Epoch 00015: val_loss did not improve from 0.51174
# Epoch 16/100
# 313/313 [==============================] - 62s 199ms/step - loss: 0.6828 - accuracy: 0.8402 - val_loss: 0.5275 - val_accuracy: 0.9062
#
# Epoch 00016: val_loss did not improve from 0.51174
# Epoch 17/100
# 313/313 [==============================] - 62s 197ms/step - loss: 0.6612 - accuracy: 0.8478 - val_loss: 0.8594 - val_accuracy: 0.7500
#
# Epoch 00017: val_loss did not improve from 0.51174
# Epoch 18/100
# 313/313 [==============================] - 63s 202ms/step - loss: 0.6811 - accuracy: 0.8426 - val_loss: 0.9522 - val_accuracy: 0.7500
#
# Epoch 00018: val_loss did not improve from 0.51174
# Epoch 19/100
# 313/313 [==============================] - 66s 212ms/step - loss: 0.6624 - accuracy: 0.8508 - val_loss: 1.2672 - val_accuracy: 0.5938
#
# Epoch 00019: val_loss did not improve from 0.51174
# Epoch 20/100
# 313/313 [==============================] - 64s 205ms/step - loss: 0.6670 - accuracy: 0.8475 - val_loss: 1.0826 - val_accuracy: 0.6562
#
# Epoch 00020: val_loss did not improve from 0.51174
# Epoch 21/100
# 313/313 [==============================] - 61s 196ms/step - loss: 0.6546 - accuracy: 0.8550 - val_loss: 0.7160 - val_accuracy: 0.7812
#
# Epoch 00021: val_loss did not improve from 0.51174
# Epoch 22/100
# 313/313 [==============================] - 61s 196ms/step - loss: 0.6357 - accuracy: 0.8596 - val_loss: 0.6368 - val_accuracy: 0.7812
#
# Epoch 00022: val_loss did not improve from 0.51174
# Epoch 23/100
# 313/313 [==============================] - 62s 198ms/step - loss: 0.6499 - accuracy: 0.8559 - val_loss: 0.8138 - val_accuracy: 0.7500
#
# Epoch 00023: val_loss did not improve from 0.51174
# Epoch 24/100
# 313/313 [==============================] - 61s 196ms/step - loss: 0.6303 - accuracy: 0.8583 - val_loss: 1.1557 - val_accuracy: 0.5938
#
# Epoch 00024: val_loss did not improve from 0.51174
# Epoch 25/100
# 313/313 [==============================] - 63s 201ms/step - loss: 0.6095 - accuracy: 0.8669 - val_loss: 1.3222 - val_accuracy: 0.6250
#
# Epoch 00025: val_loss did not improve from 0.51174
# Epoch 26/100
# 313/313 [==============================] - 62s 199ms/step - loss: 0.6200 - accuracy: 0.8628 - val_loss: 0.4552 - val_accuracy: 0.8750
#
# Epoch 00026: val_loss improved from 0.51174 to 0.45524, saving model to ./ret_model.h5
# Epoch 27/100
# 313/313 [==============================] - 62s 197ms/step - loss: 0.6008 - accuracy: 0.8619 - val_loss: 0.5876 - val_accuracy: 0.8125
#
# Epoch 00027: val_loss did not improve from 0.45524
# Epoch 28/100
# 313/313 [==============================] - 62s 197ms/step - loss: 0.6053 - accuracy: 0.8570 - val_loss: 1.1127 - val_accuracy: 0.6250
#
# Epoch 00028: val_loss did not improve from 0.45524
# Epoch 29/100
# 313/313 [==============================] - 62s 198ms/step - loss: 0.6029 - accuracy: 0.8590 - val_loss: 0.9245 - val_accuracy: 0.7188
#
# Epoch 00029: val_loss did not improve from 0.45524
# Epoch 30/100
# 313/313 [==============================] - 62s 199ms/step - loss: 0.5870 - accuracy: 0.8653 - val_loss: 0.5359 - val_accuracy: 0.9062
#
# Epoch 00030: val_loss did not improve from 0.45524
# Epoch 31/100
# 313/313 [==============================] - 63s 201ms/step - loss: 0.6144 - accuracy: 0.8623 - val_loss: 0.6061 - val_accuracy: 0.8125
#
# Epoch 00031: val_loss did not improve from 0.45524
# Epoch 32/100
# 313/313 [==============================] - 63s 201ms/step - loss: 0.5984 - accuracy: 0.8628 - val_loss: 0.6724 - val_accuracy: 0.8438
#
# Epoch 00032: val_loss did not improve from 0.45524
# Epoch 33/100
# 313/313 [==============================] - 63s 202ms/step - loss: 0.5645 - accuracy: 0.8706 - val_loss: 0.5267 - val_accuracy: 0.8438
#
# Epoch 00033: val_loss did not improve from 0.45524
# Epoch 34/100
# 313/313 [==============================] - 64s 204ms/step - loss: 0.5745 - accuracy: 0.8673 - val_loss: 0.9686 - val_accuracy: 0.7188
#
# Epoch 00034: val_loss did not improve from 0.45524
# Epoch 35/100
# 313/313 [==============================] - 64s 203ms/step - loss: 0.5999 - accuracy: 0.8611 - val_loss: 0.6887 - val_accuracy: 0.8125
#
# Epoch 00035: val_loss did not improve from 0.45524
# Epoch 36/100
# 313/313 [==============================] - 64s 204ms/step - loss: 0.5735 - accuracy: 0.8648 - val_loss: 0.6362 - val_accuracy: 0.8125
#
# Epoch 00036: val_loss did not improve from 0.45524
# Epoch 37/100
# 313/313 [==============================] - 64s 204ms/step - loss: 0.5779 - accuracy: 0.8608 - val_loss: 1.1221 - val_accuracy: 0.7188
#
# Epoch 00037: val_loss did not improve from 0.45524
# Epoch 38/100
# 313/313 [==============================] - 64s 204ms/step - loss: 0.5687 - accuracy: 0.8676 - val_loss: 0.9466 - val_accuracy: 0.8125
#
# Epoch 00038: val_loss did not improve from 0.45524
# Epoch 39/100
# 313/313 [==============================] - 64s 203ms/step - loss: 0.5535 - accuracy: 0.8717 - val_loss: 1.0181 - val_accuracy: 0.7188
#
# Epoch 00039: val_loss did not improve from 0.45524
# Epoch 40/100
# 313/313 [==============================] - 63s 201ms/step - loss: 0.5574 - accuracy: 0.8668 - val_loss: 1.3029 - val_accuracy: 0.5938
#
# Epoch 00040: val_loss did not improve from 0.45524
# Epoch 41/100
# 313/313 [==============================] - 63s 203ms/step - loss: 0.5645 - accuracy: 0.8660 - val_loss: 1.0582 - val_accuracy: 0.7812
#
# Epoch 00041: val_loss did not improve from 0.45524
# Epoch 42/100
# 313/313 [==============================] - 62s 200ms/step - loss: 0.5544 - accuracy: 0.8678 - val_loss: 1.4564 - val_accuracy: 0.6250
#
# Epoch 00042: val_loss did not improve from 0.45524
# Epoch 43/100
# 313/313 [==============================] - 65s 206ms/step - loss: 0.5447 - accuracy: 0.8721 - val_loss: 1.0648 - val_accuracy: 0.7188
#
# Epoch 00043: val_loss did not improve from 0.45524
# Epoch 44/100
# 313/313 [==============================] - 62s 196ms/step - loss: 0.5607 - accuracy: 0.8672 - val_loss: 0.9681 - val_accuracy: 0.7188
#
# Epoch 00044: val_loss did not improve from 0.45524
# Epoch 45/100
# 313/313 [==============================] - 61s 194ms/step - loss: 0.5447 - accuracy: 0.8687 - val_loss: 1.1430 - val_accuracy: 0.7500
#
# Epoch 00045: val_loss did not improve from 0.45524
# Epoch 46/100
# 313/313 [==============================] - 61s 196ms/step - loss: 0.5517 - accuracy: 0.8679 - val_loss: 0.6470 - val_accuracy: 0.8438
#
# Epoch 00046: val_loss did not improve from 0.45524
# Epoch 47/100
# 313/313 [==============================] - 61s 195ms/step - loss: 0.5408 - accuracy: 0.8725 - val_loss: 1.0054 - val_accuracy: 0.7812
#
# Epoch 00047: val_loss did not improve from 0.45524
# Epoch 48/100
# 313/313 [==============================] - 62s 197ms/step - loss: 0.5443 - accuracy: 0.8702 - val_loss: 1.0528 - val_accuracy: 0.6250
#
# Epoch 00048: val_loss did not improve from 0.45524
# Epoch 49/100
# 313/313 [==============================] - 62s 197ms/step - loss: 0.5346 - accuracy: 0.8774 - val_loss: 0.7815 - val_accuracy: 0.7812
#
# Epoch 00049: val_loss did not improve from 0.45524
# Epoch 50/100
# 313/313 [==============================] - 61s 195ms/step - loss: 0.5287 - accuracy: 0.8723 - val_loss: 0.6526 - val_accuracy: 0.8125
#
# Epoch 00050: val_loss did not improve from 0.45524
# Epoch 51/100
# 313/313 [==============================] - 61s 196ms/step - loss: 0.5276 - accuracy: 0.8771 - val_loss: 0.3527 - val_accuracy: 0.9062
#
# Epoch 00051: val_loss improved from 0.45524 to 0.35275, saving model to ./ret_model.h5
# Epoch 52/100
# 313/313 [==============================] - 61s 194ms/step - loss: 0.5358 - accuracy: 0.8720 - val_loss: 0.5854 - val_accuracy: 0.8438
#
# Epoch 00052: val_loss did not improve from 0.35275
# Epoch 53/100
# 313/313 [==============================] - 61s 195ms/step - loss: 0.5147 - accuracy: 0.8800 - val_loss: 0.6417 - val_accuracy: 0.8125
#
# Epoch 00053: val_loss did not improve from 0.35275
# Epoch 54/100
# 313/313 [==============================] - 61s 195ms/step - loss: 0.5243 - accuracy: 0.8794 - val_loss: 2.0954 - val_accuracy: 0.6250
#
# Epoch 00054: val_loss did not improve from 0.35275
# Epoch 55/100
# 313/313 [==============================] - 61s 194ms/step - loss: 0.5170 - accuracy: 0.8790 - val_loss: 0.8557 - val_accuracy: 0.6875
#
# Epoch 00055: val_loss did not improve from 0.35275
# Epoch 56/100
# 313/313 [==============================] - 61s 195ms/step - loss: 0.5083 - accuracy: 0.8802 - val_loss: 0.5134 - val_accuracy: 0.8125
#
# Epoch 00056: val_loss did not improve from 0.35275
# Epoch 57/100
# 313/313 [==============================] - 61s 194ms/step - loss: 0.5142 - accuracy: 0.8776 - val_loss: 2.1038 - val_accuracy: 0.6250
#
# Epoch 00057: val_loss did not improve from 0.35275
# Epoch 58/100
# 313/313 [==============================] - 61s 194ms/step - loss: 0.5221 - accuracy: 0.8751 - val_loss: 0.6227 - val_accuracy: 0.8438
#
# Epoch 00058: val_loss did not improve from 0.35275
# Epoch 59/100
# 313/313 [==============================] - 61s 194ms/step - loss: 0.5221 - accuracy: 0.8777 - val_loss: 0.4764 - val_accuracy: 0.8750
#
# Epoch 00059: val_loss did not improve from 0.35275
# Epoch 60/100
# 313/313 [==============================] - 61s 194ms/step - loss: 0.5099 - accuracy: 0.8796 - val_loss: 1.7824 - val_accuracy: 0.5625
#
# Epoch 00060: val_loss did not improve from 0.35275
# Epoch 61/100
# 313/313 [==============================] - 61s 193ms/step - loss: 0.5252 - accuracy: 0.8716 - val_loss: 0.7499 - val_accuracy: 0.7188
#
# Epoch 00061: val_loss did not improve from 0.35275
# Epoch 62/100
# 313/313 [==============================] - 61s 196ms/step - loss: 0.5054 - accuracy: 0.8785 - val_loss: 0.4402 - val_accuracy: 0.8750
#
# Epoch 00062: val_loss did not improve from 0.35275
# Epoch 63/100
# 313/313 [==============================] - 61s 195ms/step - loss: 0.5066 - accuracy: 0.8818 - val_loss: 1.1950 - val_accuracy: 0.6562
#
# Epoch 00063: val_loss did not improve from 0.35275
# Epoch 64/100
# 313/313 [==============================] - 62s 197ms/step - loss: 0.5035 - accuracy: 0.8834 - val_loss: 0.4120 - val_accuracy: 0.9062
#
# Epoch 00064: val_loss did not improve from 0.35275
# Epoch 65/100
# 313/313 [==============================] - 62s 197ms/step - loss: 0.5096 - accuracy: 0.8784 - val_loss: 0.5173 - val_accuracy: 0.8438
#
# Epoch 00065: val_loss did not improve from 0.35275
# Epoch 66/100
# 313/313 [==============================] - 61s 196ms/step - loss: 0.5126 - accuracy: 0.8782 - val_loss: 0.4086 - val_accuracy: 0.9375
#
# Epoch 00066: val_loss did not improve from 0.35275
# Epoch 67/100
# 313/313 [==============================] - 61s 194ms/step - loss: 0.4863 - accuracy: 0.8816 - val_loss: 1.3049 - val_accuracy: 0.6562
#
# Epoch 00067: val_loss did not improve from 0.35275
# Epoch 68/100
# 313/313 [==============================] - 61s 196ms/step - loss: 0.5012 - accuracy: 0.8794 - val_loss: 0.9289 - val_accuracy: 0.7188
#
# Epoch 00068: val_loss did not improve from 0.35275
# Epoch 69/100
# 313/313 [==============================] - 60s 193ms/step - loss: 0.4983 - accuracy: 0.8821 - val_loss: 2.0718 - val_accuracy: 0.5625
#
# Epoch 00069: val_loss did not improve from 0.35275
# Epoch 70/100
# 313/313 [==============================] - 60s 193ms/step - loss: 0.5087 - accuracy: 0.8800 - val_loss: 0.7265 - val_accuracy: 0.7500
#
# Epoch 00070: val_loss did not improve from 0.35275
# Epoch 71/100
# 313/313 [==============================] - 61s 195ms/step - loss: 0.4829 - accuracy: 0.8845 - val_loss: 0.5034 - val_accuracy: 0.8750
#
# Epoch 00071: val_loss did not improve from 0.35275
# Epoch 72/100
# 313/313 [==============================] - 60s 192ms/step - loss: 0.4972 - accuracy: 0.8804 - val_loss: 0.6919 - val_accuracy: 0.8438
#
# Epoch 00072: val_loss did not improve from 0.35275
# Epoch 73/100
# 313/313 [==============================] - 63s 201ms/step - loss: 0.4983 - accuracy: 0.8790 - val_loss: 0.8389 - val_accuracy: 0.7812
#
# Epoch 00073: val_loss did not improve from 0.35275
# Epoch 74/100
# 313/313 [==============================] - 60s 193ms/step - loss: 0.4913 - accuracy: 0.8808 - val_loss: 0.5849 - val_accuracy: 0.8438
#
# Epoch 00074: val_loss did not improve from 0.35275
# Epoch 75/100
# 313/313 [==============================] - 60s 192ms/step - loss: 0.4928 - accuracy: 0.8818 - val_loss: 0.3608 - val_accuracy: 0.9062
#
# Epoch 00075: val_loss did not improve from 0.35275
# Epoch 76/100
# 313/313 [==============================] - 60s 192ms/step - loss: 0.4887 - accuracy: 0.8826 - val_loss: 0.7618 - val_accuracy: 0.7500
#
# Epoch 00076: val_loss did not improve from 0.35275
# Epoch 77/100
# 313/313 [==============================] - 60s 193ms/step - loss: 0.5087 - accuracy: 0.8777 - val_loss: 0.3818 - val_accuracy: 0.9375
#
# Epoch 00077: val_loss did not improve from 0.35275
# Epoch 78/100
# 313/313 [==============================] - 60s 192ms/step - loss: 0.4870 - accuracy: 0.8852 - val_loss: 0.7896 - val_accuracy: 0.7188
#
# Epoch 00078: val_loss did not improve from 0.35275
# Epoch 79/100
# 313/313 [==============================] - 60s 190ms/step - loss: 0.4870 - accuracy: 0.8839 - val_loss: 1.4455 - val_accuracy: 0.6250
#
# Epoch 00079: val_loss did not improve from 0.35275
# Epoch 80/100
# 313/313 [==============================] - 60s 191ms/step - loss: 0.4896 - accuracy: 0.8869 - val_loss: 0.3288 - val_accuracy: 0.9062
#
# Epoch 00080: val_loss improved from 0.35275 to 0.32878, saving model to ./ret_model.h5
# Epoch 81/100
# 313/313 [==============================] - 61s 195ms/step - loss: 0.4837 - accuracy: 0.8829 - val_loss: 0.4955 - val_accuracy: 0.8750
#
# Epoch 00081: val_loss did not improve from 0.32878
# Epoch 82/100
# 313/313 [==============================] - 61s 194ms/step - loss: 0.4948 - accuracy: 0.8799 - val_loss: 0.7946 - val_accuracy: 0.8125
#
# Epoch 00082: val_loss did not improve from 0.32878
# Epoch 83/100
# 313/313 [==============================] - 61s 195ms/step - loss: 0.4871 - accuracy: 0.8840 - val_loss: 0.6935 - val_accuracy: 0.8125
#
# Epoch 00083: val_loss did not improve from 0.32878
# Epoch 84/100
# 313/313 [==============================] - 60s 193ms/step - loss: 0.4789 - accuracy: 0.8848 - val_loss: 0.9123 - val_accuracy: 0.8125
#
# Epoch 00084: val_loss did not improve from 0.32878
# Epoch 85/100
# 313/313 [==============================] - 61s 195ms/step - loss: 0.4915 - accuracy: 0.8834 - val_loss: 0.8706 - val_accuracy: 0.7500
#
# Epoch 00085: val_loss did not improve from 0.32878
# Epoch 86/100
# 313/313 [==============================] - 61s 195ms/step - loss: 0.4829 - accuracy: 0.8869 - val_loss: 0.5349 - val_accuracy: 0.8125
#
# Epoch 00086: val_loss did not improve from 0.32878
# Epoch 87/100
# 313/313 [==============================] - 60s 193ms/step - loss: 0.4849 - accuracy: 0.8816 - val_loss: 0.3236 - val_accuracy: 0.9062
#
# Epoch 00087: val_loss improved from 0.32878 to 0.32364, saving model to ./ret_model.h5
# Epoch 88/100
# 313/313 [==============================] - 62s 197ms/step - loss: 0.4799 - accuracy: 0.8851 - val_loss: 1.6423 - val_accuracy: 0.5938
#
# Epoch 00088: val_loss did not improve from 0.32364
# Epoch 89/100
# 313/313 [==============================] - 61s 196ms/step - loss: 0.4832 - accuracy: 0.8822 - val_loss: 1.6359 - val_accuracy: 0.6875
#
# Epoch 00089: val_loss did not improve from 0.32364
# Epoch 90/100
# 313/313 [==============================] - 62s 198ms/step - loss: 0.4839 - accuracy: 0.8819 - val_loss: 0.9527 - val_accuracy: 0.7500
#
# Epoch 00090: val_loss did not improve from 0.32364
# Epoch 91/100
# 313/313 [==============================] - 61s 195ms/step - loss: 0.4726 - accuracy: 0.8862 - val_loss: 0.7620 - val_accuracy: 0.7812
#
# Epoch 00091: val_loss did not improve from 0.32364
# Epoch 92/100
# 313/313 [==============================] - 61s 196ms/step - loss: 0.4828 - accuracy: 0.8835 - val_loss: 1.6631 - val_accuracy: 0.6250
#
# Epoch 00092: val_loss did not improve from 0.32364
# Epoch 93/100
# 313/313 [==============================] - 62s 197ms/step - loss: 0.4756 - accuracy: 0.8840 - val_loss: 1.2780 - val_accuracy: 0.5312
#
# Epoch 00093: val_loss did not improve from 0.32364
# Epoch 94/100
# 313/313 [==============================] - 62s 198ms/step - loss: 0.4896 - accuracy: 0.8825 - val_loss: 1.4377 - val_accuracy: 0.6875
#
# Epoch 00094: val_loss did not improve from 0.32364
# Epoch 95/100
# 313/313 [==============================] - 62s 197ms/step - loss: 0.4842 - accuracy: 0.8788 - val_loss: 1.0992 - val_accuracy: 0.7188
#
# Epoch 00095: val_loss did not improve from 0.32364
# Epoch 96/100
# 313/313 [==============================] - 62s 197ms/step - loss: 0.4867 - accuracy: 0.8840 - val_loss: 0.9233 - val_accuracy: 0.7188
#
# Epoch 00096: val_loss did not improve from 0.32364
# Epoch 97/100
# 313/313 [==============================] - 61s 196ms/step - loss: 0.4698 - accuracy: 0.8857 - val_loss: 0.7851 - val_accuracy: 0.8750
#
# Epoch 00097: val_loss did not improve from 0.32364
# Epoch 98/100
# 313/313 [==============================] - 61s 196ms/step - loss: 0.4731 - accuracy: 0.8879 - val_loss: 0.9067 - val_accuracy: 0.7812
#
# Epoch 00098: val_loss did not improve from 0.32364
# Epoch 99/100
# 313/313 [==============================] - 61s 195ms/step - loss: 0.4813 - accuracy: 0.8858 - val_loss: 0.4217 - val_accuracy: 0.8438
#
# Epoch 00099: val_loss did not improve from 0.32364
# Epoch 100/100
# 313/313 [==============================] - 61s 196ms/step - loss: 0.4705 - accuracy: 0.8852 - val_loss: 1.4846 - val_accuracy: 0.7188
#
# Epoch 00100: val_loss did not improve from 0.32364

# %% [markdown]
# # Loss and accuracy progression

# %%
plt.figure(figsize = (20,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Losses vs Epochs', fontsize = 20)
plt.xlabel('Epochs')
plt.ylabel('Losses')
# Out:
# Text(0, 0.5, 'Losses')

# %%
plt.figure(figsize = (20,5))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy vs Epochs', fontsize = 20)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# # Prediction

# %%
model = tf.keras.models.load_model('./ret_model.h5')

# %%
y_pred = model.predict(X_test)

# %%
y_pred = np.argmax(y_pred, axis = 1)
y_test = np.argmax(y_test, axis = 1)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
label = ['DRUSEN', 'CNV', 'NORMAL', 'DME']

# %%
print('Accuracy : ' + str(accuracy_score(y_test, y_pred)))
print(classification_report(y_test, y_pred, target_names = label))
# Out:
# Accuracy : 0.9442148760330579
#               precision    recall  f1-score   support
#
#       DRUSEN       0.97      0.98      0.97       242
#          CNV       0.97      0.92      0.94       242
#       NORMAL       0.90      1.00      0.95       242
#          DME       0.95      0.88      0.91       242
#
#     accuracy                           0.94       968
#    macro avg       0.95      0.94      0.94       968
# weighted avg       0.95      0.94      0.94       968

# %% [markdown]
# # Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
plt.figure(figsize = (12,12))
ax = seaborn.heatmap(cm, cmap=plt.cm.Greens, annot=True, square=True, xticklabels = label, yticklabels=label)
ax.set_ylabel('Actual', fontsize=40)
ax.set_xlabel('Predicted', fontsize=40)
# Out:
# Text(0.5, 145.31999999999996, 'Predicted')
